# %%
import os
import sys
import numpy as np
import pandas as pd
from pathlib import Path

sys.path.append(os.path.abspath(".."))

from utils.model_ann.ann import build_index, search

# %% [markdown]
# # Load Dataset

# %%
# 현재 Jupyter Notebook 실행 경로 (e.g., `documents/recsys/3_modeling_lightgcn`)
current_dir = os.path.abspath(os.curdir)

# `../recsys` 경로
base_dir = "/".join(current_dir.split("/")[:-1])

# 데이터셋 경로
DOMAIN = "fashion"
dataset_dir = Path(base_dir).joinpath(f"data/dataset/{DOMAIN}/interactions")

df = pd.read_parquet(dataset_dir)
df.head()
# Out:
#    user_id  item_id            timestamp action  age gender  \
# 0        1     1818  2025-09-21 03:01:00  click   46      F
# 1        1     8991  2025-09-21 03:02:00  click   46      F
# 2        1     8798  2025-09-21 03:05:00  click   46      F
# 3        1     5014  2025-09-21 03:04:00  click   46      F
# 4        1       15  2025-09-21 03:17:00  click   46      F
#
#                               title color style    fit material season sleeve  \
# 0               간절기 한정 린넨 소재 오렌지 점퍼   오렌지   빈티지    오버핏       린넨    간절기      숏
# 1              필수템! 빈티지 무드의 간절기용 점퍼   오렌지   빈티지    루즈핏       데님    간절기      롱
# 2                 세미오버핏 실루엣의 아크릴 점퍼   오렌지   빈티지  세미오버핏      아크릴    간절기      숏
# 3  겨울 시즌, 빈티지 무드의 오렌지 폴리 7부 레귤러핏 점퍼   오렌지   빈티지   레귤러핏       폴리     겨울     7부
# 4                    빈티지 무드의 오렌지 점퍼   오렌지   빈티지    슬림핏      플리스      봄      숏
#
#   category
# 0       점퍼
# 1       점퍼
# 2       점퍼
# 3       점퍼
# 4       점퍼

# %% [markdown]
# # Load Embedding Vectors

# %%
# 벡터 저장 경로 설정 (base_dir 아래에 도메인별 LightGCN 결과물이 저장된 폴더 지정)
vector_path = Path(base_dir).joinpath(f"data/model/{DOMAIN}/lightgcn")

# User / Item 벡터 파일 로드
df_user_vectors = pd.read_parquet(vector_path.joinpath("user_vector.parquet"))
df_item_vectors = pd.read_parquet(vector_path.joinpath("item_vector.parquet"))

# ID 매핑 딕셔너리 생성 (ANN 검색 후 결과를 실제 ID로 변환할 때 필요)
user_id_maps = dict(zip(df_user_vectors["idx"], df_user_vectors["user_id"]))
item_id_maps = dict(zip(df_item_vectors["idx"], df_item_vectors["item_id"]))

# 벡터(Numpy 배열) 변환
user_vectors = np.array(df_user_vectors["vector_normalized"].tolist())
item_vectors = np.array(df_item_vectors["vector_normalized"].tolist())

# 데이터 타입 변환 (ANN 라이브러리(HNSWlib, FAISS 등)에서 효율적으로 사용하기 위해 float32로 맞춤)
user_vectors = np.array(user_vectors).astype(np.float32)
item_vectors = np.array(item_vectors).astype(np.float32)

# %% [markdown]
# # Vector Similarity Search

# %% [markdown]
# ## User Similarity

# %%
# 유저 벡터 ANN 인덱스 생성
user_index = build_index(user_vectors)

# 질의할 유저 선택
user_idx = 0
query_vector = user_vectors[user_idx]  # 해당 유저의 임베딩 벡터

# ANN 검색 실행 (`query_vector`와 가장 가까운 Top-5 유저 탐색)
result = search(query_vector, user_index, top_k=5)
print(result)  # 예: {1: 0.9, 2: 0.8, ...}
# Out:
# {0: 1.0000003576278687, 1436: 0.6004522442817688, 3182: 0.5398378372192383, 3710: 0.5205610990524292, 1806: 0.4651811718940735}

# %%
# 질의 유저의 히스토리 조회 (어떤 아이템들에 관심이 있었는지)
user_id = user_id_maps[user_idx]

print(f"User ID: {user_id}")
print("-----------------------------------")
for t in sorted(df[df["user_id"] == user_id]["title"].unique()):
    print(t)
# Out:
# User ID: 1
# -----------------------------------
# 가을에 어울리는 오렌지 슬랙스
# 간절기 루즈핏 와인 데님 민소매 와이드팬츠
# 간절기 시즌, 스트리트 무드의 카키 메쉬 숏슬리브 루즈핏 조거팬츠
# 간절기 한정 린넨 소재 오렌지 점퍼
# 겨울 시즌, 빈티지 무드의 오렌지 폴리 7부 레귤러핏 점퍼
# 겨울 시즌, 캐주얼 무드의 오렌지 코튼 숏슬리브 레귤러핏 후드티
# 겨울 한정 폴리 소재 오렌지 후드티
# 봄에 어울리는 와인 와이드팬츠
# 빈티지 무드의 오렌지 점퍼
# 세미오버핏 실루엣의 아크릴 점퍼
# 오렌지 컬러의 스포티 스타일 아크릴 슬랙스
# 오버핏 실루엣의 울 슬랙스
# 와인 컬러의 포멀 스타일 레이온 와이드팬츠
# 와인 컬러의 포멀 스타일 메쉬 와이드팬츠
# 트렌디한 스포티룩, 오버핏 슬랙스 in 봄
# 트렌디한 캐주얼룩, 크롭핏 후드티 in 가을
# 필수템! 빈티지 무드의 간절기용 점퍼

# %%
# 유사 유저의 히스토리 조회 (어떤 아이템들에 관심이 있었는지)
similar_indies = list(result.keys())[1:]  # 첫 번째는 자기 자신과의 유사도이므로 제외
similar_user_ids = [user_id_maps[i] for i in similar_indies]

for uid in similar_user_ids:
    print(f"\nUser ID: {uid}")
    print("-----------------------------------")
    for t in sorted(df[df["user_id"] == uid]["title"]):
        print(t)
# Out:
# User ID: 1437
# -----------------------------------
# 가을 시즌, 모던 무드의 레드 메쉬 롱슬리브 슬림핏 후드티
# 간절기 루즈핏 와인 데님 민소매 와이드팬츠
# 간절기 크롭핏 레드 모달 숏 후드티
# 겨울 오버핏 핑크 폴리 민소매 조거팬츠
# 그레이 컬러의 포멀 스타일 코튼 블라우스
# 그레이 컬러의 포멀 스타일 폴리 블라우스
# 모던 무드의 핑크 조거팬츠
# 봄 감성 세미오버핏 가죽 조거팬츠
# 봄에 어울리는 와인 와이드팬츠
# 여름 크롭핏 레드 나일론 숏 후드티
# 여름에 어울리는 핑크 레깅스
# 와인 컬러의 포멀 스타일 레이온 와이드팬츠
# 와인 컬러의 포멀 스타일 메쉬 와이드팬츠
# 크롭핏 실루엣의 가죽 레깅스
# 크롭핏 실루엣의 아크릴 후드티
# 트렌디한 레트로룩, 크롭핏 레깅스 in 봄
# 트렌디한 모던룩, 루즈핏 조거팬츠 in 가을
# 트렌디한 모던룩, 루즈핏 후드티 in 여름
# 포멀 무드의 그레이 블라우스
#
# User ID: 3183
# -----------------------------------
# 가을 한정 모달 소재 블랙 셔츠
# 간절기 루즈핏 와인 데님 민소매 와이드팬츠
# 간절기 시즌, 레트로 무드의 아이보리 퍼 숏슬리브 오버핏 베스트
# 겨울 크롭핏 네이비 린넨 숏 카디건
# 미니멀 무드의 네이비 카디건
# 봄 한정 나일론 소재 아이보리 베스트
# 봄에 어울리는 와인 와이드팬츠
# 여름 시즌, 레트로 무드의 아이보리 폴리 롱 슬림핏 베스트
# 여름 시즌, 스트리트 무드의 그레이 아크릴 롱 세미오버핏 스커트
# 여름 크롭핏 블랙 스웨이드 민소매 셔츠
# 여름 한정 울 소재 블랙 셔츠
# 와인 컬러의 포멀 스타일 레이온 와이드팬츠
# 와인 컬러의 포멀 스타일 메쉬 와이드팬츠
#
# User ID: 3711
# -----------------------------------
# 가을 시즌, 스포티 무드의 베이지 아크릴 롱 크롭핏 점퍼
# 가을 한정 모달 소재 아이보리 후드티
# 간절기 슬림핏 라벤더 플리스 롱슬리브 니트
# 간절기 한정 린넨 소재 오렌지 점퍼
# 겨울 감성 오버핏 데님 후드티
# 겨울 시즌, 빈티지 무드의 오렌지 폴리 7부 레귤러핏 점퍼
# 라벤더 컬러의 모던 스타일 나일론 니트
# 모던 무드의 라벤더 니트
# 봄 시즌, 댄디 무드의 카키 모달 민소매 세미오버핏 후드티
# 봄 시즌, 스포티 무드의 베이지 린넨 롱 크롭핏 점퍼
# 봄 한정 레이온 소재 베이지 점퍼
# 봄 한정 메쉬 소재 카키 후드티
# 빈티지 무드의 오렌지 점퍼
# 세미오버핏 실루엣의 아크릴 점퍼
# 아이보리 컬러의 모던 스타일 데님 후드티
# 여름 시즌, 스포티 무드의 베이지 울 7부 루즈핏 점퍼
# 여름에 어울리는 아이보리 후드티
# 여름에 어울리는 오렌지 점퍼
# 오버핏 실루엣의 울 후드티
# 카키 컬러의 댄디 스타일 아크릴 후드티
# 트렌디한 댄디룩, 세미오버핏 후드티 in 겨울
# 필수템! 빈티지 무드의 간절기용 점퍼
# 필수템! 스포티 무드의 겨울용 점퍼
#
# User ID: 1807
# -----------------------------------
# 가을 한정 코튼 소재 그레이 티셔츠
# 간절기 세미오버핏 네이비 퍼 롱슬리브 스커트
# 간절기 한정 린넨 소재 오렌지 점퍼
# 겨울 시즌, 빈티지 무드의 오렌지 폴리 7부 레귤러핏 점퍼
# 겨울 한정 데님 소재 와인 맨투맨
# 겨울에 어울리는 네이비 스커트
# 레귤러핏 실루엣의 메쉬 맨투맨
# 루즈핏 실루엣의 린넨 티셔츠
# 봄 감성 크롭핏 메쉬 티셔츠
# 봄 시즌, 스트리트 무드의 와인 레이온 롱 크롭핏 맨투맨
# 빈티지 무드의 오렌지 점퍼
# 세미오버핏 실루엣의 아크릴 점퍼
# 여름 세미오버핏 네이비 린넨 민소매 스커트
# 여름 세미오버핏 네이비 모달 7부 스커트
# 여름에 어울리는 그레이 티셔츠
# 여름에 어울리는 오렌지 점퍼
# 트렌디한 포멀룩, 세미오버핏 카디건 in 봄
# 트렌디한 포멀룩, 오버핏 카디건 in 가을
# 필수템! 빈티지 무드의 간절기용 점퍼
# 필수템! 포멀 무드의 여름용 카디건

# %% [markdown]
# ## Item Similarity

# %%
# 아이템 벡터 ANN 인덱스 생성
item_index = build_index(item_vectors)

# 질의할 아이템 선택
item_idx = 0
query_vector = item_vectors[item_idx]  # 해당 아이템의 임베딩 벡터

# ANN 검색 실행 (`query_vector`와 가장 가까운 Top-5 아이템 탐색)
result = search(query_vector, item_index, top_k=5)
print(result)  # 예: {1: 0.9, 2: 0.8, ...}
# Out:
# {0: 1.0000001192092896, 5494: 0.9778155088424683, 3165: 0.9687058925628662, 51: 0.9673049449920654, 9791: 0.9619508981704712}

# %%
# 아이템 유사성을 확인하기 위한 메타 데이터 로드
item_metadata_path = Path(base_dir).joinpath(
    f"data/dataset/{DOMAIN}/item_metadata.parquet"
)
df_item = pd.read_parquet(item_metadata_path)

# %%
# 질의 아이템 제목 조회
item_id = item_id_maps[item_idx]

print(f"Item ID: {item_id}")
print(df_item[df_item["item_id"] == item_id]["title"].item())
# Out:
# Item ID: 1
# 여름에 어울리는 레드 셔츠

# %%
# 유사 아이템 제목 조회
similar_indies = list(result.keys())[1:]  # 첫 번째는 자기 자신과의 유사도이므로 제외
similar_item_ids = [item_id_maps[i] for i in similar_indies]

for item_id in similar_item_ids:
    print(f"\nItem ID: {item_id}")
    print("-----------------------------------")
    for t in sorted(df_item[df_item["item_id"] == item_id]["title"]):
        print(t)
# Out:
# Item ID: 5499
# -----------------------------------
# 레드 컬러의 러블리 스타일 울 셔츠
#
# Item ID: 3168
# -----------------------------------
# 봄에 어울리는 레드 셔츠
#
# Item ID: 52
# -----------------------------------
# 봄 한정 레이온 소재 레드 셔츠
#
# Item ID: 9796
# -----------------------------------
# 간절기 크롭핏 레드 데님 숏 셔츠

# %% [markdown]
# # Recommendation
# - User to Item 추천

# %%
# 질의 유저 선택
user_idx = 0
query_vector = user_vectors[user_idx]

# 아이템 벡터 인덱스에 질의한 결과 획득
result = search(query_vector, item_index, top_k=10)

# 추천 아이템 ID (원본 ID가 아닌 별도의 인덱스)
item_indies = list(result.keys())

# 추천 아이템 ID 재매핑
recommendation = {}
for i in item_indies:
    # 원본 ID로 매핑
    item_id = item_id_maps[i]
    recommendation[item_id] = result[i]

recommendation
# Out:
# {9118: 0.6613407135009766,
#  8805: 0.6475021243095398,
#  8691: 0.6446307301521301,
#  1671: 0.6329538226127625,
#  6118: 0.5940954685211182,
#  3865: 0.592578649520874,
#  9940: 0.5848768353462219,
#  3155: 0.5834989547729492,
#  8991: 0.5784054398536682,
#  8363: 0.5764095783233643}

# %%
# 추천 아이템 상세 보기
df_recommendation = df_item[
    df_item["item_id"].isin(list(recommendation.keys()))
].reset_index(drop=True)

# 추천 아이템 점수(유사도) 추가
df_recommendation["score"] = df_recommendation["item_id"].map(recommendation)

# 점수별 내림차순 정렬
df_recommendation = df_recommendation.sort_values(
    "score", ascending=False, ignore_index=True
)

# %%
# 해당 유저의 히스토리 조회
df[df["user_id"] == user_id_maps[user_idx]].reset_index(drop=True)
# Out:
#     user_id  item_id            timestamp    action  age gender  \
# 0         1     1818  2025-09-21 03:01:00     click   46      F
# 1         1     8991  2025-09-21 03:02:00     click   46      F
# 2         1     8798  2025-09-21 03:05:00     click   46      F
# 3         1     5014  2025-09-21 03:04:00     click   46      F
# 4         1       15  2025-09-21 03:17:00     click   46      F
# 5         1     8363  2025-09-19 08:51:00     click   46      F
# 6         1     9596  2025-09-19 08:53:00  purchase   46      F
# 7         1     9940  2025-09-19 08:57:00     click   46      F
# 8         1     5840  2025-09-13 03:22:00     click   46      F
# 9         1     3155  2025-09-18 03:59:00     click   46      F
# 10        1     4339  2025-09-18 04:00:00     click   46      F
# 11        1     3865  2025-09-18 04:05:00  purchase   46      F
# 12        1     6118  2025-09-18 04:05:00  wishlist   46      F
# 13        1     8691  2025-09-13 08:29:00     click   46      F
# 14        1     9118  2025-09-13 08:30:00     click   46      F
# 15        1     8805  2025-09-13 08:33:00     click   46      F
# 16        1     1671  2025-09-13 08:35:00     click   46      F
#
#                                    title color style    fit material season  \
# 0                    간절기 한정 린넨 소재 오렌지 점퍼   오렌지   빈티지    오버핏       린넨    간절기
# 1                   필수템! 빈티지 무드의 간절기용 점퍼   오렌지   빈티지    루즈핏       데님    간절기
# 2                      세미오버핏 실루엣의 아크릴 점퍼   오렌지   빈티지  세미오버핏      아크릴    간절기
# 3       겨울 시즌, 빈티지 무드의 오렌지 폴리 7부 레귤러핏 점퍼   오렌지   빈티지   레귤러핏       폴리     겨울
# 4                         빈티지 무드의 오렌지 점퍼   오렌지   빈티지    슬림핏      플리스      봄
# 5                    겨울 한정 폴리 소재 오렌지 후드티   오렌지   캐주얼    크롭핏       폴리     겨울
# 6    겨울 시즌, 캐주얼 무드의 오렌지 코튼 숏슬리브 레귤러핏 후드티   오렌지   캐주얼   레귤러핏       코튼     겨울
# 7               트렌디한 캐주얼룩, 크롭핏 후드티 in 가을   오렌지   캐주얼    크롭핏       가죽     가을
# 8   간절기 시즌, 스트리트 무드의 카키 메쉬 숏슬리브 루즈핏 조거팬츠    카키  스트리트    루즈핏       메쉬    간절기
# 9                       가을에 어울리는 오렌지 슬랙스   오렌지   스포티    루즈핏       린넨     가을
# 10               오렌지 컬러의 스포티 스타일 아크릴 슬랙스   오렌지   스포티    크롭핏      아크릴     여름
# 11                        오버핏 실루엣의 울 슬랙스   오렌지   스포티    오버핏        울      봄
# 12               트렌디한 스포티룩, 오버핏 슬랙스 in 봄   오렌지   스포티    오버핏      레이온      봄
# 13                와인 컬러의 포멀 스타일 메쉬 와이드팬츠    와인    포멀    슬림핏       메쉬    간절기
# 14               와인 컬러의 포멀 스타일 레이온 와이드팬츠    와인    포멀   레귤러핏      레이온     겨울
# 15                      봄에 어울리는 와인 와이드팬츠    와인    포멀    루즈핏       폴리      봄
# 16               간절기 루즈핏 와인 데님 민소매 와이드팬츠    와인    포멀    루즈핏       데님    간절기
#
#    sleeve category
# 0       숏       점퍼
# 1       롱       점퍼
# 2       숏       점퍼
# 3      7부       점퍼
# 4       숏       점퍼
# 5     민소매      후드티
# 6    숏슬리브      후드티
# 7    롱슬리브      후드티
# 8    숏슬리브     조거팬츠
# 9     민소매      슬랙스
# 10   롱슬리브      슬랙스
# 11      숏      슬랙스
# 12     7부      슬랙스
# 13      숏    와이드팬츠
# 14      숏    와이드팬츠
# 15    민소매    와이드팬츠
# 16    민소매    와이드팬츠

# %%
# 추천 아이템 최종 후보군 조회
df_recommendation
# Out:
#    item_id                     title color style   fit material season sleeve  \
# 0     9118   와인 컬러의 포멀 스타일 레이온 와이드팬츠    와인    포멀  레귤러핏      레이온     겨울      숏
# 1     8805          봄에 어울리는 와인 와이드팬츠    와인    포멀   루즈핏       폴리      봄    민소매
# 2     8691    와인 컬러의 포멀 스타일 메쉬 와이드팬츠    와인    포멀   슬림핏       메쉬    간절기      숏
# 3     1671   간절기 루즈핏 와인 데님 민소매 와이드팬츠    와인    포멀   루즈핏       데님    간절기    민소매
# 4     6118   트렌디한 스포티룩, 오버핏 슬랙스 in 봄   오렌지   스포티   오버핏      레이온      봄     7부
# 5     3865            오버핏 실루엣의 울 슬랙스   오렌지   스포티   오버핏        울      봄      숏
# 6     9940  트렌디한 캐주얼룩, 크롭핏 후드티 in 가을   오렌지   캐주얼   크롭핏       가죽     가을   롱슬리브
# 7     3155          가을에 어울리는 오렌지 슬랙스   오렌지   스포티   루즈핏       린넨     가을    민소매
# 8     8991      필수템! 빈티지 무드의 간절기용 점퍼   오렌지   빈티지   루즈핏       데님    간절기      롱
# 9     8363       겨울 한정 폴리 소재 오렌지 후드티   오렌지   캐주얼   크롭핏       폴리     겨울    민소매
#
#   category     score
# 0    와이드팬츠  0.661341
# 1    와이드팬츠  0.647502
# 2    와이드팬츠  0.644631
# 3    와이드팬츠  0.632954
# 4      슬랙스  0.594095
# 5      슬랙스  0.592579
# 6      후드티  0.584877
# 7      슬랙스  0.583499
# 8       점퍼  0.578405
# 9      후드티  0.576410
