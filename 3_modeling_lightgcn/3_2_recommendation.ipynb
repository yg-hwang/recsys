# %%
import os
import sys
import numpy as np
import pandas as pd
from pathlib import Path

sys.path.append(os.path.abspath(".."))

from utils.model_ann.ann import build_index, search

# %% [markdown]
# # Load Dataset

# %%
# 현재 Jupyter Notebook 실행 경로 (e.g., `documents/recsys/3_modeling_lightgcn`)
current_dir = os.path.abspath(os.curdir)

# `../recsys` 경로
base_dir = "/".join(current_dir.split("/")[:-1])

# 데이터셋 경로
DOMAIN = "fashion"
dataset_dir = Path(base_dir).joinpath(f"data/dataset/{DOMAIN}/interactions")

df = pd.read_parquet(dataset_dir)
df.head()
# Out:
#    user_id  item_id            timestamp action  age gender  \
# 0        1      345  2025-09-21 03:01:00  click   46      F
# 1        1     8718  2025-09-21 03:02:00  click   46      F
# 2        1     8191  2025-09-21 03:05:00  click   46      F
# 3        1       39  2025-09-21 03:04:00  click   46      F
# 4        1      993  2025-09-21 03:17:00  click   46      F
#
#                            title color style  fit material season sleeve  \
# 0  봄 시즌, 시크 무드의 베이지 퍼 7부 슬림핏 스커트   베이지    시크  슬림핏        퍼      봄     7부
# 1             필수템! 시크 무드의 봄용 스커트   베이지    시크  크롭핏      나일론      봄   숏슬리브
# 2               가을에 어울리는 베이지 스커트   베이지    시크  크롭핏      나일론     가을      숏
# 3               봄 감성 슬림핏 플리스 스커트   베이지    시크  슬림핏      플리스      봄   롱슬리브
# 4                 시크 무드의 베이지 스커트   베이지    시크  슬림핏       코튼     가을    민소매
#
#   category
# 0      스커트
# 1      스커트
# 2      스커트
# 3      스커트
# 4      스커트

# %% [markdown]
# # Load Embedding Vectors

# %%
# 벡터 저장 경로 설정 (base_dir 아래에 도메인별 LightGCN 결과물이 저장된 폴더 지정)
vector_path = Path(base_dir).joinpath(f"data/model/{DOMAIN}/lightgcn")

# User / Item 벡터 파일 로드
df_user_vectors = pd.read_parquet(vector_path.joinpath("user_vector.parquet"))
df_item_vectors = pd.read_parquet(vector_path.joinpath("item_vector.parquet"))

# ID 매핑 딕셔너리 생성 (ANN 검색 후 결과를 실제 ID로 변환할 때 필요)
user_id_maps = dict(zip(df_user_vectors["idx"], df_user_vectors["user_id"]))
item_id_maps = dict(zip(df_item_vectors["idx"], df_item_vectors["item_id"]))

# 벡터(Numpy 배열) 변환
user_vectors = np.array(df_user_vectors["vector_normalized"].tolist())
item_vectors = np.array(df_item_vectors["vector_normalized"].tolist())

# 데이터 타입 변환 (ANN 라이브러리(HNSWlib, FAISS 등)에서 효율적으로 사용하기 위해 float32로 맞춤)
user_vectors = np.array(user_vectors).astype(np.float32)
item_vectors = np.array(item_vectors).astype(np.float32)

# %% [markdown]
# # Vector Similarity Search

# %% [markdown]
# ## User Similarity

# %%
# 유저 벡터 ANN 인덱스 생성
user_index = build_index(user_vectors)

# 질의할 유저 선택
user_idx = 0
query_vector = user_vectors[user_idx]  # 해당 유저의 임베딩 벡터

# ANN 검색 실행 (`query_vector`와 가장 가까운 Top-5 유저 탐색)
result = search(query_vector, user_index, top_k=5)
print(result)  # 예: {1: 0.9, 2: 0.8, ...}
# Out:
# {0: 1.0000001192092896, 3649: 0.5718045234680176, 6427: 0.5383899807929993, 9611: 0.5135765075683594, 4292: 0.49620580673217773}

# %%
# 질의 유저의 히스토리 조회 (어떤 아이템들에 관심이 있었는지)
user_id = user_id_maps[user_idx]

print(f"User ID: {user_id}")
print("-----------------------------------")
for t in sorted(df[df["user_id"] == user_id]["title"].unique()):
    print(t)
# Out:
# User ID: 1
# -----------------------------------
# 가을에 어울리는 베이지 스커트
# 간절기 감성 루즈핏 폴리 셔츠
# 간절기에 어울리는 화이트 조거팬츠
# 겨울 감성 세미오버핏 가죽 조거팬츠
# 겨울 크롭핏 화이트 플리스 숏 조거팬츠
# 러블리 무드의 화이트 조거팬츠
# 루즈핏 실루엣의 모달 티셔츠
# 봄 감성 슬림핏 플리스 스커트
# 봄 레귤러핏 화이트 모달 숏 티셔츠
# 봄 시즌, 시크 무드의 베이지 퍼 7부 슬림핏 스커트
# 시크 무드의 베이지 스커트
# 여름 감성 루즈핏 나일론 셔츠
# 오렌지 컬러의 러블리 스타일 메쉬 셔츠
# 트렌디한 러블리룩, 슬림핏 셔츠 in 간절기
# 트렌디한 스포티룩, 오버핏 트레이닝세트 in 가을
# 필수템! 러블리 무드의 겨울용 조거팬츠
# 필수템! 시크 무드의 봄용 스커트
# 필수템! 캐주얼 무드의 가을용 티셔츠

# %%
# 유사 유저의 히스토리 조회 (어떤 아이템들에 관심이 있었는지)
similar_indies = list(result.keys())[1:]  # 첫 번째는 자기 자신과의 유사도이므로 제외
similar_user_ids = [user_id_maps[i] for i in similar_indies]

for uid in similar_user_ids:
    print(f"\nUser ID: {uid}")
    print("-----------------------------------")
    for t in sorted(df[df["user_id"] == uid]["title"]):
        print(t)
# Out:
# User ID: 3650
# -----------------------------------
# 간절기에 어울리는 그레이 슬랙스
# 간절기에 어울리는 화이트 조거팬츠
# 겨울 감성 세미오버핏 가죽 조거팬츠
# 겨울 크롭핏 화이트 플리스 숏 조거팬츠
# 러블리 무드의 화이트 조거팬츠
# 레귤러핏 실루엣의 메쉬 슬랙스
# 미니멀 무드의 그레이 슬랙스
# 미니멀 무드의 네이비 코트
# 블랙 컬러의 포멀 스타일 메쉬 조거팬츠
# 블랙 컬러의 포멀 스타일 폴리 조거팬츠
# 빈티지 무드의 오렌지 맨투맨
# 여름 감성 오버핏 스웨이드 슬랙스
# 여름 시즌, 빈티지 무드의 오렌지 아크릴 롱슬리브 레귤러핏 맨투맨
# 여름 한정 스웨이드 소재 블랙 조거팬츠
# 크롭핏 실루엣의 모달 맨투맨
# 필수템! 러블리 무드의 겨울용 조거팬츠
# 화이트 컬러의 러블리 스타일 레이온 조거팬츠
#
# User ID: 6428
# -----------------------------------
# 가을 시즌, 시크 무드의 핑크 아크릴 숏슬리브 크롭핏 와이드팬츠
# 가을에 어울리는 베이지 스커트
# 겨울 루즈핏 아이보리 나일론 민소매 코트
# 봄 감성 슬림핏 플리스 스커트
# 봄 시즌, 댄디 무드의 라벤더 가죽 롱 세미오버핏 조거팬츠
# 봄 시즌, 시크 무드의 베이지 퍼 7부 슬림핏 스커트
# 브라운 컬러의 레트로 스타일 린넨 슬랙스
# 시크 무드의 핑크 와이드팬츠
# 아이보리 컬러의 미니멀 스타일 폴리 코트
# 여름 한정 모달 소재 베이지 스커트
# 오버핏 실루엣의 가죽 와이드팬츠
# 트렌디한 댄디룩, 오버핏 조거팬츠 in 겨울
# 트렌디한 미니멀룩, 슬림핏 코트 in 여름
# 트렌디한 시크룩, 레귤러핏 와이드팬츠 in 여름
# 필수템! 댄디 무드의 가을용 조거팬츠
# 필수템! 댄디 무드의 간절기용 조거팬츠
# 필수템! 레트로 무드의 여름용 슬랙스
# 필수템! 시크 무드의 봄용 스커트
#
# User ID: 9612
# -----------------------------------
# 간절기 한정 가죽 소재 아이보리 트레이닝세트
# 간절기에 어울리는 카키 셔츠
# 겨울 오버핏 그레이 플리스 롱슬리브 블라우스
# 그레이 컬러의 포멀 스타일 나일론 블라우스
# 루즈핏 실루엣의 데님 트레이닝세트
# 루즈핏 실루엣의 모달 티셔츠
# 봄 레귤러핏 화이트 모달 숏 티셔츠
# 봄 시즌, 캐주얼 무드의 아이보리 퍼 롱 루즈핏 트레이닝세트
# 블랙 컬러의 포멀 스타일 메쉬 조거팬츠
# 블랙 컬러의 포멀 스타일 폴리 조거팬츠
# 아이보리 컬러의 캐주얼 스타일 코튼 트레이닝세트
# 여름 감성 슬림핏 가죽 블라우스
# 여름 크롭핏 카키 레이온 민소매 셔츠
# 여름 한정 스웨이드 소재 블랙 조거팬츠
# 필수템! 캐주얼 무드의 가을용 티셔츠
#
# User ID: 4293
# -----------------------------------
# 겨울 감성 루즈핏 아크릴 맨투맨
# 겨울 시즌, 캐주얼 무드의 올리브 아크릴 롱 세미오버핏 셔츠
# 겨울 오버핏 브라운 아크릴 숏 맨투맨
# 겨울 한정 메쉬 소재 올리브 셔츠
# 봄 시즌, 스트리트 무드의 핑크 모달 롱 세미오버핏 와이드팬츠
# 봄 시즌, 시크 무드의 베이지 퍼 7부 슬림핏 스커트
# 세미오버핏 실루엣의 코튼 와이드팬츠
# 슬림핏 실루엣의 데님 와이드팬츠
# 여름 슬림핏 베이지 플리스 7부 스커트
# 여름 한정 나일론 소재 브라운 맨투맨
# 오버핏 실루엣의 코튼 셔츠
# 올리브 컬러의 캐주얼 스타일 데님 셔츠
# 트렌디한 시크룩, 슬림핏 맨투맨 in 간절기
# 트렌디한 캐주얼룩, 레귤러핏 셔츠 in 겨울
# 트렌디한 캐주얼룩, 슬림핏 셔츠 in 가을
# 필수템! 시크 무드의 봄용 스커트
# 핑크 컬러의 스트리트 스타일 가죽 와이드팬츠

# %% [markdown]
# ## Item Similarity

# %%
# 아이템 벡터 ANN 인덱스 생성
item_index = build_index(item_vectors)

# 질의할 아이템 선택
item_idx = 0
query_vector = item_vectors[item_idx]  # 해당 아이템의 임베딩 벡터

# ANN 검색 실행 (`query_vector`와 가장 가까운 Top-5 아이템 탐색)
result = search(query_vector, item_index, top_k=5)
print(result)  # 예: {1: 0.9, 2: 0.8, ...}
# Out:
# {0: 1.000000238418579, 3425: 0.9736729264259338, 1944: 0.9722357988357544, 8271: 0.9665869474411011, 146: 0.9441960453987122}

# %%
# 아이템 유사성을 확인하기 위한 메타 데이터 로드
item_metadata_path = Path(base_dir).joinpath(
    f"data/dataset/{DOMAIN}/item_metadata.parquet"
)
df_item = pd.read_parquet(item_metadata_path)

# %%
# 질의 아이템 제목 조회
item_id = item_id_maps[item_idx]

print(f"Item ID: {item_id}")
print(df_item[df_item["item_id"] == item_id]["title"].item())
# Out:
# Item ID: 1
# 트렌디한 캐주얼룩, 오버핏 재킷 in 겨울

# %%
# 유사 아이템 제목 조회
similar_indies = list(result.keys())[1:]  # 첫 번째는 자기 자신과의 유사도이므로 제외
similar_item_ids = [item_id_maps[i] for i in similar_indies]

for item_id in similar_item_ids:
    print(f"\nItem ID: {item_id}")
    print("-----------------------------------")
    for t in sorted(df_item[df_item["item_id"] == item_id]["title"]):
        print(t)
# Out:
# Item ID: 3428
# -----------------------------------
# 캐주얼 무드의 와인 재킷
#
# Item ID: 1945
# -----------------------------------
# 봄 한정 플리스 소재 와인 재킷
#
# Item ID: 8274
# -----------------------------------
# 루즈핏 실루엣의 모달 재킷
#
# Item ID: 147
# -----------------------------------
# 간절기 크롭핏 와인 메쉬 숏 재킷

# %% [markdown]
# # Recommendation
# - User to Item 추천

# %%
# 질의 유저 선택
user_idx = 0
query_vector = user_vectors[user_idx]

# 아이템 벡터 인덱스에 질의한 결과 획득
result = search(query_vector, item_index, top_k=10)

# 추천 아이템 ID (원본 ID가 아닌 별도의 인덱스)
item_indies = list(result.keys())

# 추천 아이템 ID 재매핑
recommendation = {}
for i in item_indies:
    # 원본 ID로 매핑
    item_id = item_id_maps[i]
    recommendation[item_id] = result[i]

recommendation
# Out:
# {8718: 0.7502506375312805,
#  345: 0.7074130177497864,
#  993: 0.7035366892814636,
#  39: 0.7021253108978271,
#  8191: 0.6967242360115051,
#  6571: 0.6460009217262268,
#  5377: 0.6192914843559265,
#  9265: 0.6040363907814026,
#  9780: 0.5964839458465576,
#  1108: 0.5893169641494751}

# %%
# 추천 아이템 상세 보기
df_recommendation = df_item[
    df_item["item_id"].isin(list(recommendation.keys()))
].reset_index(drop=True)

# 추천 아이템 점수(유사도) 추가
df_recommendation["score"] = df_recommendation["item_id"].map(recommendation)

# 점수별 내림차순 정렬
df_recommendation = df_recommendation.sort_values(
    "score", ascending=False, ignore_index=True
)

# %%
# 해당 유저의 히스토리 조회
df[df["user_id"] == user_id_maps[user_idx]].reset_index(drop=True)
# Out:
#     user_id  item_id            timestamp    action  age gender  \
# 0         1      345  2025-09-21 03:01:00     click   46      F
# 1         1     8718  2025-09-21 03:02:00     click   46      F
# 2         1     8191  2025-09-21 03:05:00     click   46      F
# 3         1       39  2025-09-21 03:04:00     click   46      F
# 4         1      993  2025-09-21 03:17:00     click   46      F
# 5         1      371  2025-09-19 08:51:00     click   46      F
# 6         1      234  2025-09-05 06:48:00  wishlist   46      F
# 7         1     9780  2025-09-05 06:51:00  wishlist   46      F
# 8         1     1108  2025-09-05 06:56:00     click   46      F
# 9         1     6382  2025-09-05 07:00:00     click   46      F
# 10        1     5506  2025-09-10 20:39:00     click   46      F
# 11        1      782  2025-09-10 20:42:00  purchase   46      F
# 12        1     4136  2025-09-10 20:43:00  wishlist   46      F
# 13        1     4983  2025-09-13 08:29:00     click   46      F
# 14        1     5988  2025-09-13 08:30:00     click   46      F
# 15        1     9124  2025-09-13 08:33:00     click   46      F
# 16        1     9265  2025-09-13 08:35:00     click   46      F
# 17        1     8190  2025-09-13 08:45:00     click   46      F
#
#                             title color style    fit material season sleeve  \
# 0   봄 시즌, 시크 무드의 베이지 퍼 7부 슬림핏 스커트   베이지    시크    슬림핏        퍼      봄     7부
# 1              필수템! 시크 무드의 봄용 스커트   베이지    시크    크롭핏      나일론      봄   숏슬리브
# 2                가을에 어울리는 베이지 스커트   베이지    시크    크롭핏      나일론     가을      숏
# 3                봄 감성 슬림핏 플리스 스커트   베이지    시크    슬림핏      플리스      봄   롱슬리브
# 4                  시크 무드의 베이지 스커트   베이지    시크    슬림핏       코튼     가을    민소매
# 5     트렌디한 스포티룩, 오버핏 트레이닝세트 in 가을   라벤더   스포티    오버핏       모달     가을   숏슬리브
# 6                여름 감성 루즈핏 나일론 셔츠   오렌지   러블리    루즈핏      나일론     여름   숏슬리브
# 7           오렌지 컬러의 러블리 스타일 메쉬 셔츠   오렌지   러블리  세미오버핏       메쉬    간절기      롱
# 8                간절기 감성 루즈핏 폴리 셔츠   오렌지   러블리    루즈핏       폴리    간절기   숏슬리브
# 9        트렌디한 러블리룩, 슬림핏 셔츠 in 간절기   오렌지   러블리    슬림핏       린넨    간절기   롱슬리브
# 10                루즈핏 실루엣의 모달 티셔츠   화이트   캐주얼    루즈핏       모달     여름     7부
# 11           필수템! 캐주얼 무드의 가을용 티셔츠   화이트   캐주얼   레귤러핏     스웨이드     가을     7부
# 12            봄 레귤러핏 화이트 모달 숏 티셔츠   화이트   캐주얼   레귤러핏       모달      봄      숏
# 13          필수템! 러블리 무드의 겨울용 조거팬츠   화이트   러블리    루즈핏        퍼     겨울   롱슬리브
# 14               러블리 무드의 화이트 조거팬츠   화이트   러블리    오버핏       가죽     가을      숏
# 15          겨울 크롭핏 화이트 플리스 숏 조거팬츠   화이트   러블리    크롭핏      플리스     겨울      숏
# 16            겨울 감성 세미오버핏 가죽 조거팬츠   화이트   러블리  세미오버핏       가죽     겨울     7부
# 17             간절기에 어울리는 화이트 조거팬츠   화이트   러블리    크롭핏      플리스    간절기      숏
#
#    category
# 0       스커트
# 1       스커트
# 2       스커트
# 3       스커트
# 4       스커트
# 5    트레이닝세트
# 6        셔츠
# 7        셔츠
# 8        셔츠
# 9        셔츠
# 10      티셔츠
# 11      티셔츠
# 12      티셔츠
# 13     조거팬츠
# 14     조거팬츠
# 15     조거팬츠
# 16     조거팬츠
# 17     조거팬츠

# %%
# 추천 아이템 최종 후보군 조회
df_recommendation
# Out:
#    item_id                          title color style    fit material season  \
# 0     8718             필수템! 시크 무드의 봄용 스커트   베이지    시크    크롭핏      나일론      봄
# 1      345  봄 시즌, 시크 무드의 베이지 퍼 7부 슬림핏 스커트   베이지    시크    슬림핏        퍼      봄
# 2      993                 시크 무드의 베이지 스커트   베이지    시크    슬림핏       코튼     가을
# 3       39               봄 감성 슬림핏 플리스 스커트   베이지    시크    슬림핏      플리스      봄
# 4     8191               가을에 어울리는 베이지 스커트   베이지    시크    크롭핏      나일론     가을
# 5     6571          여름 슬림핏 베이지 플리스 7부 스커트   베이지    시크    슬림핏      플리스     여름
# 6     5377            여름 한정 모달 소재 베이지 스커트   베이지    시크  세미오버핏       모달     여름
# 7     9265            겨울 감성 세미오버핏 가죽 조거팬츠   화이트   러블리  세미오버핏       가죽     겨울
# 8     9780          오렌지 컬러의 러블리 스타일 메쉬 셔츠   오렌지   러블리  세미오버핏       메쉬    간절기
# 9     1108               간절기 감성 루즈핏 폴리 셔츠   오렌지   러블리    루즈핏       폴리    간절기
#
#   sleeve category     score
# 0   숏슬리브      스커트  0.750251
# 1     7부      스커트  0.707413
# 2    민소매      스커트  0.703537
# 3   롱슬리브      스커트  0.702125
# 4      숏      스커트  0.696724
# 5     7부      스커트  0.646001
# 6   숏슬리브      스커트  0.619291
# 7     7부     조거팬츠  0.604036
# 8      롱       셔츠  0.596484
# 9   숏슬리브       셔츠  0.589317
